-- %% [markdown]
-- # Quest to Delta Optimisation - Fabric
--
-- We will explore the following:
--  - V-Order
--
-- *NB:*
-- - *Demo focuses on the Speed of Creating and Flexiblity of the techniques rather than Query Performance!*

-- %% [markdown]
-- ## **Setup**
--
-- Let's start by cleaning up the environment.

-- %% [markdown]
-- ### Delete Exsiting Tables & Files

-- %%
DROP TABLE IF EXISTS delta_optimize.customer;
DROP TABLE IF EXISTS delta_optimize.customer_vo;
-- Out:
-- StatementMeta(, 4502ef8f-5222-4b18-8238-f9b57389b830, 44, Finished, Available, Finished)
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>

-- %% [markdown]
-- ## **V-Order**
--
-- V-Order is a write time optimization to the parquet file format that enables fast reads.

-- %% [markdown]
-- ### **Delta table <u>without</u> V-Order**
--
-- Create and query a Delta table with V-Order disabled.

-- %% [markdown]
-- #### **Create and Populate a Delta table**
--
-- - Disable `V-Order`
-- - Create Delta table
-- - Insert **`Dummy`** Data into Delta table

-- %% [markdown]
-- ##### Disable `V-Order`

-- %%
SET spark.sql.parquet.vorder.enabled=FALSE
-- Out:
-- StatementMeta(, 4502ef8f-5222-4b18-8238-f9b57389b830, 45, Finished, Available, Finished)
-- <Spark SQL result set with 1 rows and 2 fields>

-- %% [markdown]
-- ##### Create Delta table

-- %%
-- Create Table
CREATE TABLE IF NOT EXISTS delta_optimize.customer
  (ID INT, customer_name STRING, street STRING, city STRING, district STRING, state STRING, postcode STRING, region STRING)
USING DELTA;
-- Out:
-- StatementMeta(, 4502ef8f-5222-4b18-8238-f9b57389b830, 46, Finished, Available, Finished)
-- <Spark SQL result set with 0 rows and 0 fields>

-- %% [markdown]
-- ##### Insert Data into Delta table
--
--
-- **RESULT:** *Runtime ~52 sec*

-- %%
-- Insert Data
INSERT INTO delta_optimize.customer(ID, customer_name, street, city, district, state, postcode, region)
	VALUES (1, 'Alice Johnson', '123 Maple St', 'London', 'Camden', 'Greater London', 'NW1 5DB', 'England');
INSERT INTO delta_optimize.customer(ID, customer_name, street, city, district, state, postcode, region)
	VALUES (2, 'Bob Smith', '456 Oak Ave', 'Manchester', 'Didsbury', 'Greater Manchester', 'M20 2UF', 'England');
INSERT INTO delta_optimize.customer(ID, customer_name, street, city, district, state, postcode, region)
	VALUES (3, 'Charlie Brown', '789 Pine Rd', 'Birmingham', 'Edgbaston', 'West Midlands', 'B15 2TT', 'England');
INSERT INTO delta_optimize.customer(ID, customer_name, street, city, district, state, postcode, region)
	VALUES (4, 'David Miller', '101 Birch Blvd', 'Edinburgh', 'Leith', 'City of Edinburgh', 'EH6 6NZ', 'Scotland');
INSERT INTO delta_optimize.customer(ID, customer_name, street, city, district, state, postcode, region)
	VALUES (5, 'Eva White', '202 Cedar Ln', 'Glasgow', 'Hillhead', 'Glasgow City', 'G12 8QQ', 'Scotland');
INSERT INTO delta_optimize.customer(ID, customer_name, street, city, district, state, postcode, region)
	VALUES (6, 'Frank Harris', '303 Elm St', 'Bristol', 'Clifton', 'Bristol', 'BS8 1UD', 'England');
INSERT INTO delta_optimize.customer(ID, customer_name, street, city, district, state, postcode, region)
	VALUES (7, 'Grace Lee', '404 Willow Dr', 'Liverpool', 'Wavertree', 'Merseyside', 'L15 1HN', 'England');
INSERT INTO delta_optimize.customer(ID, customer_name, street, city, district, state, postcode, region)
	VALUES (8, 'Henry Clark', '505 Aspen Ct', 'Cardiff', 'Roath', 'Cardiff', 'CF24 3EX', 'Wales');
INSERT INTO delta_optimize.customer(ID, customer_name, street, city, district, state, postcode, region)
	VALUES (9, 'Isabella Davis', '606 Spruce Ave', 'Belfast', 'Botanic', 'Belfast', 'BT7 1NN', 'Northern Ireland');
INSERT INTO delta_optimize.customer(ID, customer_name, street, city, district, state, postcode, region)
	VALUES (10, 'Jack Wilson', '707 Redwood Way', 'Oxford', 'Headington', 'Oxfordshire', 'OX3 9DU', 'England');
-- Out:
-- StatementMeta(, 4502ef8f-5222-4b18-8238-f9b57389b830, 56, Finished, Available, Finished)
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>

-- %% [markdown]
-- #### **Query the Delta table**
--
-- Query and observe the new execution run time
--
-- **RESULT:** *Runtime ~6 seconds*

-- %%
SELECT *
FROM delta_optimize.customer
-- Out:
-- StatementMeta(, 4502ef8f-5222-4b18-8238-f9b57389b830, 57, Finished, Available, Finished)
-- <Spark SQL result set with 10 rows and 8 fields>

-- %% [markdown]
-- #### **Query the Delta table metadata**
--
-- Get the table Metadata using **`DESCRIBE DETAIL`** statement
--
-- **RESULT:** *NumFiles = `10`*

-- %%
DESCRIBE DETAIL delta_optimize.customer
-- Out:
-- StatementMeta(, 4502ef8f-5222-4b18-8238-f9b57389b830, 58, Finished, Available, Finished)
-- <Spark SQL result set with 1 rows and 14 fields>

-- %% [markdown]
-- #### **Query the Delta files**

-- %%
%%pyspark

mssparkutils.fs.ls("Tables/customer")
-- Out:
-- StatementMeta(, 4502ef8f-5222-4b18-8238-f9b57389b830, 59, Finished, Available, Finished)
-- [FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer/_delta_log, name=_delta_log, size=0),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer/part-00000-03f573b5-ad22-4783-b5c0-8df58f3301ff-c000.snappy.parquet, name=part-00000-03f573b5-ad22-4783-b5c0-8df58f3301ff-c000.snappy.parquet, size=3947),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer/part-00000-44b1ebed-2bf6-4dda-b3fa-c18f0e328176-c000.snappy.parquet, name=part-00000-44b1ebed-2bf6-4dda-b3fa-c18f0e328176-c000.snappy.parquet, size=3898),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer/part-00000-602aca97-45e3-46c0-b8e4-2b5abc21458a-c000.snappy.parquet, name=part-00000-602aca97-45e3-46c0-b8e4-2b5abc21458a-c000.snappy.parquet, size=3905),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer/part-00000-75563649-d696-4128-ae99-878f32ef2707-c000.snappy.parquet, name=part-00000-75563649-d696-4128-ae99-878f32ef2707-c000.snappy.parquet, size=3926),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer/part-00000-77340dce-ed16-402b-9db7-d07b53598841-c000.snappy.parquet, name=part-00000-77340dce-ed16-402b-9db7-d07b53598841-c000.snappy.parquet, size=3842),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer/part-00000-8da45a4a-ee8d-4003-a0b9-0d43b4c34913-c000.snappy.parquet, name=part-00000-8da45a4a-ee8d-4003-a0b9-0d43b4c34913-c000.snappy.parquet, size=3961),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer/part-00000-8dc04910-7019-4131-a75a-6932de90ba34-c000.snappy.parquet, name=part-00000-8dc04910-7019-4131-a75a-6932de90ba34-c000.snappy.parquet, size=3947),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer/part-00000-cdff16eb-100c-40c5-8a75-28ace467171d-c000.snappy.parquet, name=part-00000-cdff16eb-100c-40c5-8a75-28ace467171d-c000.snappy.parquet, size=3961),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer/part-00000-d5417269-b27a-4f7a-a81c-b2c70388cb48-c000.snappy.parquet, name=part-00000-d5417269-b27a-4f7a-a81c-b2c70388cb48-c000.snappy.parquet, size=3912),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer/part-00000-e69b98f7-bda0-40c1-a4fb-11219bec6872-c000.snappy.parquet, name=part-00000-e69b98f7-bda0-40c1-a4fb-11219bec6872-c000.snappy.parquet, size=3856)]

-- %% [markdown]
-- ### **Delta Table <u>with</u> V-Order**
--
--
-- Create and query a Delta table with V-Order Enabled.

-- %% [markdown]
-- #### **Create and Populate a Delta table**
--
-- - Enable `V-Order`
-- - Create Delta table
-- - Insert Data into Delta Table

-- %% [markdown]
-- ##### Enable `V-Order`

-- %%
SET spark.sql.parquet.vorder.enabled = TRUE
-- Out:
-- StatementMeta(, 4502ef8f-5222-4b18-8238-f9b57389b830, 60, Finished, Available, Finished)
-- <Spark SQL result set with 1 rows and 2 fields>

-- %% [markdown]
-- ##### Create Delta table

-- %%
-- Create Table
CREATE TABLE IF NOT EXISTS delta_optimize.customer_vo
  (ID INT, customer_name STRING, street STRING, city STRING, district STRING, state STRING, postcode STRING, region STRING)
USING DELTA;
-- Out:
-- StatementMeta(, 4502ef8f-5222-4b18-8238-f9b57389b830, 61, Finished, Available, Finished)
-- <Spark SQL result set with 0 rows and 0 fields>

-- %% [markdown]
-- ##### Insert Data into Delta table
--
--
-- **RESULT:** *Runtime ~30 sec*

-- %%
INSERT INTO delta_optimize.customer_vo(ID, customer_name, street, city, district, state, postcode, region)
	VALUES (1, 'Alice Johnson', '123 Maple St', 'London', 'Camden', 'Greater London', 'NW1 5DB', 'England');
INSERT INTO delta_optimize.customer_vo(ID, customer_name, street, city, district, state, postcode, region)
	VALUES (2, 'Bob Smith', '456 Oak Ave', 'Manchester', 'Didsbury', 'Greater Manchester', 'M20 2UF', 'England');
INSERT INTO delta_optimize.customer_vo(ID, customer_name, street, city, district, state, postcode, region)
	VALUES (3, 'Charlie Brown', '789 Pine Rd', 'Birmingham', 'Edgbaston', 'West Midlands', 'B15 2TT', 'England');
INSERT INTO delta_optimize.customer_vo(ID, customer_name, street, city, district, state, postcode, region)
	VALUES (4, 'David Miller', '101 Birch Blvd', 'Edinburgh', 'Leith', 'City of Edinburgh', 'EH6 6NZ', 'Scotland');
INSERT INTO delta_optimize.customer_vo(ID, customer_name, street, city, district, state, postcode, region)
	VALUES (5, 'Eva White', '202 Cedar Ln', 'Glasgow', 'Hillhead', 'Glasgow City', 'G12 8QQ', 'Scotland');
INSERT INTO delta_optimize.customer_vo(ID, customer_name, street, city, district, state, postcode, region)
	VALUES (6, 'Frank Harris', '303 Elm St', 'Bristol', 'Clifton', 'Bristol', 'BS8 1UD', 'England');
INSERT INTO delta_optimize.customer_vo(ID, customer_name, street, city, district, state, postcode, region)
	VALUES (7, 'Grace Lee', '404 Willow Dr', 'Liverpool', 'Wavertree', 'Merseyside', 'L15 1HN', 'England');
INSERT INTO delta_optimize.customer_vo(ID, customer_name, street, city, district, state, postcode, region)
	VALUES (8, 'Henry Clark', '505 Aspen Ct', 'Cardiff', 'Roath', 'Cardiff', 'CF24 3EX', 'Wales');
INSERT INTO delta_optimize.customer_vo(ID, customer_name, street, city, district, state, postcode, region)
	VALUES (9, 'Isabella Davis', '606 Spruce Ave', 'Belfast', 'Botanic', 'Belfast', 'BT7 1NN', 'Northern Ireland');
INSERT INTO delta_optimize.customer_vo(ID, customer_name, street, city, district, state, postcode, region)
	VALUES (10, 'Jack Wilson', '707 Redwood Way', 'Oxford', 'Headington', 'Oxfordshire', 'OX3 9DU', 'England');
-- Out:
-- StatementMeta(, 4502ef8f-5222-4b18-8238-f9b57389b830, 71, Finished, Available, Finished)
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>

-- %% [markdown]
-- #### **Query the Delta table**
--
-- Query and observe the new execution run time
--
-- **RESULT:** *Runtime ~2 seconds*

-- %%
SELECT *
FROM delta_optimize.customer_vo
-- Out:
-- StatementMeta(, 4502ef8f-5222-4b18-8238-f9b57389b830, 72, Finished, Available, Finished)
-- <Spark SQL result set with 10 rows and 8 fields>

-- %% [markdown]
-- #### **Query the Delta table metadata**
--
-- Get the table Metadata using **`DESCRIBE DETAIL`** statement
--
-- **RESULT:** *NumFiles = `10`*

-- %%
DESCRIBE DETAIL delta_optimize.customer_vo
-- Out:
-- StatementMeta(, 4502ef8f-5222-4b18-8238-f9b57389b830, 73, Finished, Available, Finished)
-- <Spark SQL result set with 1 rows and 14 fields>

-- %% [markdown]
-- #### **Query the Delta files**

-- %%
%%pyspark

mssparkutils.fs.ls("Tables/customer_vo")
-- Out:
-- StatementMeta(, 4502ef8f-5222-4b18-8238-f9b57389b830, 74, Finished, Available, Finished)
-- [FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/_delta_log, name=_delta_log, size=0),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/part-00000-0bacfd76-53c4-48e7-a7c0-01c2eb68d9d1-c000.snappy.parquet, name=part-00000-0bacfd76-53c4-48e7-a7c0-01c2eb68d9d1-c000.snappy.parquet, size=3927),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/part-00000-1bc8e128-c290-4f7b-9367-1a3827456b90-c000.snappy.parquet, name=part-00000-1bc8e128-c290-4f7b-9367-1a3827456b90-c000.snappy.parquet, size=4032),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/part-00000-80968b50-a943-4653-8260-19cdbccab3d0-c000.snappy.parquet, name=part-00000-80968b50-a943-4653-8260-19cdbccab3d0-c000.snappy.parquet, size=3983),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/part-00000-8c64830c-ab1a-481b-aefb-a1c1e6bb8d7e-c000.snappy.parquet, name=part-00000-8c64830c-ab1a-481b-aefb-a1c1e6bb8d7e-c000.snappy.parquet, size=3990),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/part-00000-a2e2483a-a562-4139-8d7c-eab20f75eba9-c000.snappy.parquet, name=part-00000-a2e2483a-a562-4139-8d7c-eab20f75eba9-c000.snappy.parquet, size=3941),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/part-00000-af3fd1ac-af18-4296-8bcc-e1fd61257bc4-c000.snappy.parquet, name=part-00000-af3fd1ac-af18-4296-8bcc-e1fd61257bc4-c000.snappy.parquet, size=4011),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/part-00000-b2868a1f-f4aa-4ebf-907b-9e0abefe3337-c000.snappy.parquet, name=part-00000-b2868a1f-f4aa-4ebf-907b-9e0abefe3337-c000.snappy.parquet, size=3997),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/part-00000-b30d78ff-e684-41a3-b134-50e9a13f57f8-c000.snappy.parquet, name=part-00000-b30d78ff-e684-41a3-b134-50e9a13f57f8-c000.snappy.parquet, size=4046),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/part-00000-c76dfbcd-48f5-48e8-8e93-1cd88c54768f-c000.snappy.parquet, name=part-00000-c76dfbcd-48f5-48e8-8e93-1cd88c54768f-c000.snappy.parquet, size=4032),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/part-00000-d63e7168-35e7-45c3-815a-58387c387bca-c000.snappy.parquet, name=part-00000-d63e7168-35e7-45c3-815a-58387c387bca-c000.snappy.parquet, size=4046)]

-- %% [markdown]
-- ## **Maintenance**

-- %% [markdown]
-- ### **OPTIMIZE**
--
-- Optimize the Lakehouse with the OPTIMIZE command.

-- %% [markdown]
-- #### **'OPTIMIZE' the Delta table**

-- %%
OPTIMIZE delta_optimize.customer_vo VORDER;
-- Out:
-- StatementMeta(, 4502ef8f-5222-4b18-8238-f9b57389b830, 75, Finished, Available, Finished)
-- <Spark SQL result set with 1 rows and 2 fields>

-- %% [markdown]
-- #### **Query the Delta files**

-- %%
%%pyspark

mssparkutils.fs.ls("Tables/customer_vo/_delta_log")
-- Out:
-- StatementMeta(, 4502ef8f-5222-4b18-8238-f9b57389b830, 76, Finished, Available, Finished)
-- [FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/_delta_log/00000000000000000000.json, name=00000000000000000000.json, size=1255),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/_delta_log/00000000000000000001.json, name=00000000000000000001.json, size=1181),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/_delta_log/00000000000000000002.json, name=00000000000000000002.json, size=1191),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/_delta_log/00000000000000000003.json, name=00000000000000000003.json, size=1191),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/_delta_log/00000000000000000004.json, name=00000000000000000004.json, size=1195),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/_delta_log/00000000000000000005.json, name=00000000000000000005.json, size=1177),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/_delta_log/00000000000000000006.json, name=00000000000000000006.json, size=1165),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/_delta_log/00000000000000000007.json, name=00000000000000000007.json, size=1179),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/_delta_log/00000000000000000008.json, name=00000000000000000008.json, size=1161),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/_delta_log/00000000000000000009.json, name=00000000000000000009.json, size=1195),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/_delta_log/00000000000000000010.checkpoint.parquet, name=00000000000000000010.checkpoint.parquet, size=18316),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/_delta_log/00000000000000000010.json, name=00000000000000000010.json, size=1187),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/_delta_log/00000000000000000011.json, name=00000000000000000011.json, size=3673),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/_delta_log/_last_checkpoint, name=_last_checkpoint, size=4140),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/_delta_log/_temporary, name=_temporary, size=0)]

-- %% [markdown]
-- #### **Query the Delta JSON log**

-- %%
%%pyspark

file_path = "Tables/customer_vo/_delta_log/00000000000000000011.json"

df = spark.read.json(file_path)
display(df)
-- Out:
-- StatementMeta(, 4502ef8f-5222-4b18-8238-f9b57389b830, 78, Finished, Available, Finished)
-- SynapseWidget(Synapse.DataFrame, 1f08ce78-cdea-41a7-83c6-8a77b47508df)

-- %% [markdown]
-- #### View the Delta Files & Delta JSON Log in the Lakehouse Explorer

-- %% [markdown]
-- ### **Vacuum**
--
-- Remove Stale Parquet Files with the VACUUM Command

-- %%
SET spark.databricks.delta.retentionDurationCheck.enabled = false;
-- Out:
-- StatementMeta(, 4502ef8f-5222-4b18-8238-f9b57389b830, 79, Finished, Available, Finished)
-- <Spark SQL result set with 1 rows and 2 fields>

-- %% [markdown]
-- #### **Vacuum to Remove Old Files**
--
-- Clean up stale files in Delta Lake tables using the **`VACUUM`** operation.

-- %%
VACUUM delta_optimize.customer_vo RETAIN 0 HOURS;
-- Out:
-- StatementMeta(, 4502ef8f-5222-4b18-8238-f9b57389b830, 80, Finished, Available, Finished)
-- <Spark SQL result set with 1 rows and 1 fields>

-- %% [markdown]
-- #### **Query the Delta files**
--
-- **RESULT:** *The stale files removed*

-- %%
%%pyspark

mssparkutils.fs.ls("Tables/customer_vo/")
-- Out:
-- StatementMeta(, 4502ef8f-5222-4b18-8238-f9b57389b830, 81, Finished, Available, Finished)
-- [FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/_delta_log, name=_delta_log, size=0),
--  FileInfo(path=abfss://50c55be7-4da3-490d-9c86-9314a3e32f8c@onelake.dfs.fabric.microsoft.com/0c12c4f6-13d0-4783-8479-d48f32286840/Tables/customer_vo/part-00000-d1766a08-e4b4-43dd-8f40-f1165576e5e8-c000.snappy.parquet, name=part-00000-d1766a08-e4b4-43dd-8f40-f1165576e5e8-c000.snappy.parquet, size=4830)]

-- %% [markdown]
-- Notebook finished.
